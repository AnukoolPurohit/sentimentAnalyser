# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from functools import partial
from sentimentanalyser.data.text import TextList, ItemList, DataBunch, SplitData
from sentimentanalyser.utils.data import Path, listify, random_splitter, compose, parallel, pad_collate, parent_labeler, read_wiki
from sentimentanalyser.data.samplers import SortishSampler, SortSampler
from sentimentanalyser.utils.preprocessing import *
from sentimentanalyser.utils.files import pickle_dump, pickle_load
from sentimentanalyser.preprocessing.processor import TokenizerProcessor, NuemericalizeProcessor, CategoryProcessor
# Out:
# /home/anukoolpurohit/anaconda3/envs/Torch10cuda/lib/python3.7/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
path_imdb = Path("/home/anukoolpurohit/Documents/AnukoolPurohit/Datasets/imdb")

# %%
tl = TextList.from_files(path_imdb, folders=['train', 'test', 'unsup'])
sd_imdb = tl.split_by_func(partial(random_splitter, p=[0.9,0.1]))

# %%
proc_tok = TokenizerProcessor()
proc_num = NuemericalizeProcessor()
proc_cat = CategoryProcessor()

# %%
# %time sd_imdb = sd_imdb.label_by_func(parent_labeler, proc_x=[proc_tok, proc_num], proc_y=proc_cat)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/data/text.py in label_by_func(self, func, proc_x, proc_y)
#     130
#     131     def label_by_func(self, func, proc_x=None, proc_y=None):
# --> 132         train = LabeledData.label_by_func(self.train, func, proc_x=proc_x, proc_y=proc_y)
#     133         valid = LabeledData.label_by_func(self.valid, func, proc_x=proc_x, proc_y=proc_y)
#     134         if self.test is not None:
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/data/text.py in label_by_func(cls, il, func, proc_x, proc_y)
#     185     @classmethod
#     186     def label_by_func(cls, il, func, proc_x=None, proc_y=None):
# --> 187         return cls(il, cls._label_by_func(func, il), proc_x=proc_x, proc_y=proc_y)
#     188
#     189
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/data/text.py in __init__(self, x, y, proc_x, proc_y)
#     162 class LabeledData():
#     163     def __init__(self, x, y, proc_x=None, proc_y=None):
# --> 164         self.x = self.process(x, proc_x)
#     165         self.y = self.process(y, proc_y)
#     166         self.proc_x = proc_x
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/data/text.py in process(self, il, process)
#     168
#     169     def process(self, il, process):
# --> 170         return il.new(compose(il, process))
#     171
#     172     def __repr__(self):
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/utils/data.py in compose(x, funcs, order_attr, **kwargs)
#      23     key = lambda o : getattr(o, order_attr, 0)
#      24     for func in sorted(listify(funcs), key=key):
# ---> 25         x = func(x, **kwargs)
#      26     return x
#      27
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/preprocessing/processor.py in __call__(self, items)
#      37
#      38     def __call__(self, items):
# ---> 39         chunks = [items[i:i+self.chunksize] for i in range(0, len(items), self.chunksize)]
#      40         toks = parallel(self.process, chunks, max_workers=self.max_workers)
#      41         return sum(toks, [])
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/preprocessing/processor.py in <listcomp>(.0)
#      37
#      38     def __call__(self, items):
# ---> 39         chunks = [items[i:i+self.chunksize] for i in range(0, len(items), self.chunksize)]
#      40         toks = parallel(self.process, chunks, max_workers=self.max_workers)
#      41         return sum(toks, [])
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/data/text.py in __getitem__(self, idx)
#      73         item = super().__getitem__(idx)
#      74         if isinstance(item, list):
# ---> 75             return [self._get(i) for i in item]
#      76         return self._get(item)
#      77
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/data/text.py in <listcomp>(.0)
#      73         item = super().__getitem__(idx)
#      74         if isinstance(item, list):
# ---> 75             return [self._get(i) for i in item]
#      76         return self._get(item)
#      77
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/data/text.py in _get(self, i)
#      68
#      69     def _get(self, i):
# ---> 70         return compose(self.get(i), self.tfms)
#      71
#      72     def __getitem__(self, idx):
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/data/text.py in get(self, i)
#     101     def get(self, i):
#     102         if isinstance(i, Path):
# --> 103             return read_text_file(i)
#     104         return i
#     105
#
# ~/Documents/Workspace/MachineLearningExperiment/Text-Experiments/Sentiment Analysis/sentimentanalyser/utils/data.py in read_text_file(file)
#      28 def read_text_file(file):
#      29     with open(file, 'r', encoding='utf8') as f:
# ---> 30         return f.read()
#      31
#      32 def filter_files(files, include=[], exclude=[], attr=None):
#
# ~/anaconda3/envs/Torch10cuda/lib/python3.7/codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
#
# KeyboardInterrupt:

# %%
pickle_dump(sd_imdb, 'dumps/variable/sd_imdb.pickle')

# %%
sd_imdb = pickle_load('dumps/variable/sd_imdb.pickle')

# %%
path_wiki = Path("/home/anukoolpurohit/Documents/AnukoolPurohit/Datasets/wikitext-103")

# %%
train = TextList(read_wiki(path_wiki/'train.txt'), path=path_wiki)
valid = TextList(read_wiki(path_wiki/'valid.txt'), path=path_wiki)

# %%
len(train), len(valid)
# Out:
# (28476, 60)

# %%
sd_wiki = SplitData(train, valid)

# %%
proc_tok_wiki, proc_num_wiki = TokenizerProcessor(), NuemericalizeProcessor()

# %%
sd_wiki = sd_wiki.label_by_func(lambda x:0, proc_x=[proc_tok_wiki,proc_num_wiki], proc_y=None)
# Out:
# HBox(children=(IntProgress(value=0, max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))

# %%
pickle_dump(sd_wiki, 'dumps/variable/sd_wiki.pickle')

# %%
sd_wiki = pickle_load('dumps/variable/sd_wiki.pickle')

# %%
wiki_data = sd_wiki.lm_databunchify(64, 70)

# %%
x1,y1 = next(iter(wiki_data.valid_dl))

# %%
imdb_data = sd_imdb.clas_databunchify(64)

# %%
x1,y1 = next(iter(imdb_data.valid_dl))

# %%
set([y for y in sd_imdb.train.y])
# Out:
# {0, 1, 2}

# %%
y1
# Out:
# tensor([1, 1, 0, 2, 2, 0, 1, 2, 2, 2, 2, 1, 2, 0, 1, 2, 0, 1, 2, 1, 2, 0, 2, 2,
#         0, 2, 1, 2, 0, 0, 2, 1, 0, 0, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 1, 2,
#         1, 2, 2, 1, 0, 1, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 1, 1, 2, 2, 2,
#         2, 2, 0, 2, 0, 2, 2, 2, 2, 0, 2, 2, 0, 0, 2, 2, 0, 2, 1, 1, 2, 1, 2, 2,
#         1, 1, 1, 2, 2, 0, 2, 2, 2, 0, 0, 1, 2, 1, 0, 2, 0, 1, 0, 1, 1, 0, 2, 1,
#         2, 2, 0, 2, 2, 0, 1, 1])

# %%
import torch
from torch import nn
from fastai import *

# %%
proc_num.vocab_size
# Out:
# 60000

# %%
class Model0(nn.Module):
    def __init__(self):
        self.embedding = nn.Embedding(proc_num.vocab_size, 50)
        self.fc1       = nn.Linear(50, 256)
        self.fc2       = nn.Linear(256, 2)

# %%
clf = SimpleRNNClassifier(proc_num.vocab_size, 10, 50, 2, 2, 0.5, 1)

# %%
y1 = clf(x1)
# Out:
# torch.Size([4, 64, 50])
# torch.Size([4, 64, 50])

# %%
x1.shape
# Out:
# torch.Size([64, 70])

# %%
y1.shape
# Out:
# torch.Size([4, 64, 2])

# %%
proc_num.vocab
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxrep',
#  'xxwrep',
#  'xxup',
#  'xxmaj',
#  'the',
#  '.',
#  ',',
#  'and',
#  'a',
#  'of',
#  'to',
#  'is',
#  'it',
#  'in',
#  'I',
#  'this',
#  'that',
#  '"',
#  "'s",
#  '-',
#  '\n\n',
#  'was',
#  'as',
#  'with',
#  'for',
#  'movie',
#  'but',
#  'film',
#  'you',
#  ')',
#  'on',
#  "n't",
#  '(',
#  'not',
#  'are',
#  'he',
#  'his',
#  'have',
#  'one',
#  'be',
#  'all',
#  'at',
#  'they',
#  'by',
#  'an',
#  'who',
#  '!',
#  'from',
#  'so',
#  'like',
#  'there',
#  'or',
#  'just',
#  'her',
#  'do',
#  'about',
#  'has',
#  'out',
#  "'",
#  'if',
#  'what',
#  'some',
#  '?',
#  'good',
#  'when',
#  'more',
#  'very',
#  'she',
#  'up',
#  'would',
#  'no',
#  'time',
#  'even',
#  'my',
#  'can',
#  'their',
#  'which',
#  'story',
#  'only',
#  'really',
#  'see',
#  'had',
#  'were',
#  'did',
#  'well',
#  'me',
#  'we',
#  'does',
#  '...',
#  'than',
#  'much',
#  ':',
#  'could',
#  'bad',
#  'get',
#  'been',
#  'people',
#  'great',
#  'other',
#  'also',
#  'into',
#  'will',
#  'first',
#  'because',
#  'him',
#  'how',
#  'most',
#  'them',
#  'its',
#  'make',
#  'made',
#  'then',
#  'way',
#  'too',
#  'movies',
#  'after',
#  'any',
#  'characters',
#  'think',
#  'character',
#  'films',
#  '/',
#  'two',
#  'watch',
#  'being',
#  'many',
#  'plot',
#  'seen',
#  'never',
#  'love',
#  ';',
#  'where',
#  'life',
#  'acting',
#  'little',
#  'best',
#  'know',
#  'A',
#  'off',
#  'over',
#  'show',
#  'ever',
#  'man',
#  'better',
#  'your',
#  'here',
#  'scene',
#  'end',
#  'these',
#  'still',
#  'while',
#  'why',
#  'should',
#  'say',
#  'scenes',
#  'i',
#  'something',
#  'go',
#  "'ve",
#  'such',
#  'back',
#  'through',
#  'real',
#  'those',
#  'now',
#  "'m",
#  'watching',
#  'thing',
#  'actors',
#  'director',
#  'funny',
#  'though',
#  'years',
#  'another',
#  'old',
#  'actually',
#  'makes',
#  'work',
#  'nothing',
#  'before',
#  'going',
#  '10',
#  'new',
#  'look',
#  'find',
#  'same',
#  '--',
#  'lot',
#  'few',
#  'every',
#  'part',
#  'again',
#  '*',
#  'world',
#  'cast',
#  'ca',
#  'things',
#  '&',
#  'horror',
#  'us',
#  "'re",
#  'want',
#  'down',
#  'quite',
#  'pretty',
#  'got',
#  'around',
#  'seems',
#  'young',
#  'action',
#  'fact',
#  'take',
#  'thought',
#  'long',
#  'however',
#  'enough',
#  'both',
#  'big',
#  'give',
#  'own',
#  'comedy',
#  '4',
#  'between',
#  'must',
#  'may',
#  'series',
#  'right',
#  'without',
#  'guy',
#  'role',
#  'times',
#  'interesting',
#  'saw',
#  'always',
#  'original',
#  'come',
#  'music',
#  'gets',
#  'whole',
#  'almost',
#  'point',
#  'least',
#  'bit',
#  'done',
#  'script',
#  'far',
#  'last',
#  'feel',
#  'minutes',
#  'since',
#  'making',
#  'might',
#  'family',
#  'anything',
#  'girl',
#  'performance',
#  'probably',
#  "'ll",
#  'am',
#  'away',
#  'yet',
#  'tv',
#  '2',
#  'kind',
#  'hard',
#  'fun',
#  'woman',
#  'rather',
#  'worst',
#  'day',
#  'anyone',
#  'found',
#  'sure',
#  'each',
#  'played',
#  'especially',
#  'looking',
#  'our',
#  'trying',
#  'having',
#  'screen',
#  'believe',
#  'although',
#  'different',
#  'set',
#  'course',
#  'place',
#  'goes',
#  'dvd',
#  'sense',
#  'ending',
#  'worth',
#  'comes',
#  'shows',
#  'three',
#  'maybe',
#  'everything',
#  'american',
#  'put',
#  'once',
#  'money',
#  'effects',
#  'let',
#  'actor',
#  'main',
#  'book',
#  'someone',
#  'looks',
#  'together',
#  'reason',
#  'everyone',
#  'plays',
#  'true',
#  'job',
#  'during',
#  'instead',
#  "'d",
#  'war',
#  'watched',
#  'play',
#  'high',
#  'john',
#  'said',
#  'takes',
#  'special',
#  'later',
#  'seem',
#  'audience',
#  'night',
#  'half',
#  'black',
#  'himself',
#  'wife',
#  'seeing',
#  'left',
#  'beautiful',
#  'idea',
#  'death',
#  'star',
#  'year',
#  'shot',
#  'used',
#  'excellent',
#  'else',
#  'house',
#  'simply',
#  'men',
#  'second',
#  'mind',
#  'completely',
#  'fan',
#  'dead',
#  'father',
#  'version',
#  'budget',
#  'poor',
#  'nice',
#  'less',
#  'along',
#  'hollywood',
#  'boring',
#  'help',
#  'home',
#  'short',
#  'line',
#  'top',
#  'women',
#  'sex',
#  'either',
#  '5',
#  'kids',
#  'friends',
#  'read',
#  'camera',
#  'performances',
#  'try',
#  'use',
#  'wrong',
#  'couple',
#  'low',
#  'given',
#  '1',
#  'need',
#  'until',
#  'next',
#  '3',
#  'enjoy',
#  'classic',
#  'start',
#  'production',
#  'full',
#  'truly',
#  'stupid',
#  'school',
#  'rest',
#  'video',
#  'mother',
#  '..',
#  'awful',
#  'tell',
#  'getting',
#  'moments',
#  'perhaps',
#  'mean',
#  'recommend',
#  'terrible',
#  'keep',
#  'came',
#  'itself',
#  'understand',
#  'face',
#  'name',
#  'small',
#  'others',
#  'style',
#  'wonderful',
#  'remember',
#  'playing',
#  'boy',
#  'doing',
#  'person',
#  'definitely',
#  'often',
#  'dialogue',
#  'human',
#  'stars',
#  'early',
#  'gives',
#  'perfect',
#  'lines',
#  'live',
#  'lost',
#  'written',
#  'head',
#  'went',
#  'case',
#  'entertaining',
#  'title',
#  'children',
#  'yes',
#  'friend',
#  'episode',
#  'certainly',
#  'hope',
#  'become',
#  'piece',
#  'liked',
#  'absolutely',
#  'sort',
#  'oh',
#  'finally',
#  'laugh',
#  'picture',
#  'guys',
#  'based',
#  'several',
#  'cinema',
#  'worse',
#  'drama',
#  'problem',
#  'entire',
#  'called',
#  'fans',
#  'supposed',
#  'felt',
#  'overall',
#  'against',
#  'humor',
#  'under',
#  'direction',
#  'lead',
#  'waste',
#  'care',
#  'lives',
#  'beginning',
#  'loved',
#  'son',
#  'game',
#  'seemed',
#  'evil',
#  'dark',
#  'totally',
#  'white',
#  'despite',
#  'final',
#  'wanted',
#  'killer',
#  'wo',
#  'able',
#  'throughout',
#  'turn',
#  'guess',
#  'becomes',
#  'history',
#  'already',
#  'sound',
#  'unfortunately',
#  'days',
#  'genre',
#  'town',
#  'fine',
#  'heart',
#  'side',
#  'run',
#  'today',
#  'quality',
#  'wants',
#  'flick',
#  'horrible',
#  'act',
#  'example',
#  'kill',
#  'city',
#  'tries',
#  'close',
#  'writing',
#  'matter',
#  'viewer',
#  'turns',
#  'amazing',
#  'hand',
#  'past',
#  'parts',
#  'child',
#  'car',
#  'killed',
#  'enjoyed',
#  '\x96',
#  'themselves',
#  'starts',
#  'etc',
#  'expect',
#  'works',
#  'directed',
#  'stuff',
#  'favorite',
#  'gave',
#  'kid',
#  'group',
#  'michael',
#  'behind',
#  'soon',
#  'daughter',
#  'decent',
#  'stop',
#  'type',
#  'brilliant',
#  'obviously',
#  'eyes',
#  'fight',
#  'thinking',
#  'actress',
#  'art',
#  'sometimes',
#  'known',
#  'self',
#  'blood',
#  'girls',
#  'god',
#  'late',
#  'myself',
#  'violence',
#  'hour',
#  'except',
#  'says',
#  'highly',
#  'took',
#  'writer',
#  'heard',
#  'stories',
#  'coming',
#  'happens',
#  'feeling',
#  'experience',
#  'slow',
#  'leave',
#  'police',
#  'hero',
#  'voice',
#  'extremely',
#  'happened',
#  'anyway',
#  'moment',
#  'roles',
#  'score',
#  'hell',
#  'involved',
#  'murder',
#  'husband',
#  'looked',
#  'obvious',
#  'including',
#  'attempt',
#  'cool',
#  'taken',
#  'wonder',
#  'save',
#  'living',
#  'strong',
#  'told',
#  'ok',
#  'happen',
#  'mr.',
#  'david',
#  'chance',
#  'hilarious',
#  'cut',
#  'interest',
#  'age',
#  'robert',
#  'simple',
#  'none',
#  'hours',
#  'hit',
#  'gore',
#  'brother',
#  'particularly',
#  'lack',
#  'please',
#  'across',
#  'ago',
#  'career',
#  'complete',
#  'james',
#  'crap',
#  'serious',
#  'exactly',
#  'seriously',
#  'possible',
#  'song',
#  'documentary',
#  'important',
#  'annoying',
#  'sad',
#  'running',
#  'reality',
#  'relationship',
#  'usually',
#  'alone',
#  'shown',
#  'jokes',
#  'talent',
#  'light',
#  'power',
#  'number',
#  'opening',
#  'level',
#  'english',
#  'whose',
#  'released',
#  'order',
#  'female',
#  'ends',
#  'middle',
#  'call',
#  'saying',
#  'taking',
#  'cinematography',
#  'happy',
#  'wish',
#  'ridiculous',
#  'country',
#  'body',
#  'mostly',
#  'turned',
#  'view',
#  'change',
#  'somewhat',
#  'yourself',
#  'huge',
#  'scary',
#  'four',
#  'room',
#  'silly',
#  'usual',
#  'strange',
#  'shots',
#  'started',
#  'basically',
#  'finds',
#  'word',
#  'major',
#  'apparently',
#  'disappointed',
#  'attention',
#  'beyond',
#  'miss',
#  'novel',
#  'talking',
#  'jack',
#  'opinion',
#  'words',
#  'single',
#  'modern',
#  'cheap',
#  'non',
#  'knows',
#  'french',
#  'knew',
#  'due',
#  'thriller',
#  'rating',
#  'clearly',
#  'problems',
#  '7',
#  'straight',
#  'sequel',
#  'ones',
#  'future',
#  'talk',
#  'upon',
#  'british',
#  'sets',
#  'fast',
#  'die',
#  'events',
#  'earth',
#  'tells',
#  'local',
#  'comic',
#  'parents',
#  'entertainment',
#  'add',
#  'dialog',
#  'television',
#  'king',
#  'class',
#  'ten',
#  'giving',
#  'bring',
#  'team',
#  'hate',
#  'sequence',
#  'easily',
#  'george',
#  'lots',
#  'review',
#  'five',
#  'clear',
#  'similar',
#  'above',
#  'predictable',
#  'musical',
#  'within',
#  'appears',
#  'storyline',
#  '8',
#  'easy',
#  'near',
#  'space',
#  'enjoyable',
#  'romantic',
#  'mention',
#  'falls',
#  'typical',
#  'ways',
#  'certain',
#  'working',
#  'episodes',
#  'moving',
#  'bunch',
#  'filmed',
#  'message',
#  'supporting',
#  'whether',
#  'stand',
#  'named',
#  'eye',
#  'release',
#  'songs',
#  'monster',
#  'general',
#  'crime',
#  'sorry',
#  'surprised',
#  'dull',
#  'mystery',
#  'suspense',
#  'stay',
#  'theme',
#  'fall',
#  'among',
#  'soundtrack',
#  'begins',
#  'elements',
#  'B',
#  'gay',
#  'tried',
#  'avoid',
#  'gone',
#  'tale',
#  'using',
#  'showing',
#  'points',
#  'effort',
#  'needs',
#  'viewers',
#  'theater',
#  'dog',
#  'kept',
#  'york',
#  'red',
#  'sister',
#  'feels',
#  'buy',
#  'comments',
#  'america',
#  'tom',
#  'richard',
#  'doubt',
#  'leads',
#  'means',
#  'okay',
#  'rent',
#  'brought',
#  'viewing',
#  'killing',
#  'feature',
#  'herself',
#  'realistic',
#  'period',
#  'lady',
#  'nearly',
#  'sequences',
#  'fantastic',
#  'editing',
#  'follow',
#  'form',
#  'forget',
#  'peter',
#  'deal',
#  'somehow',
#  'de',
#  'move',
#  'truth',
#  'believable',
#  '9',
#  'check',
#  'material',
#  'famous',
#  'fi',
#  'third',
#  'rock',
#  'imagine',
#  'average',
#  'sci',
#  'reviews',
#  'cop',
#  'deep',
#  'surprise',
#  'greatest',
#  'premise',
#  'paul',
#  'subject',
#  'figure',
#  'poorly',
#  'lee',
#  'oscar',
#  'actual',
#  'weak',
#  'whatever',
#  'eventually',
#  're',
#  'hear',
#  'learn',
#  'animation',
#  'atmosphere',
#  'sit',
#  'free',
#  'indeed',
#  'lame',
#  'open',
#  'expected',
#  'possibly',
#  'western',
#  'crew',
#  'wait',
#  'note',
#  'leaves',
#  'difficult',
#  'minute',
#  'box',
#  'forced',
#  'situation',
#  '6',
#  'decided',
#  'society',
#  'sexual',
#  'romance',
#  'otherwise',
#  'begin',
#  '$',
#  'acted',
#  'plus',
#  'reading',
#  '20',
#  'shame',
#  'hot',
#  'became',
#  'stage',
#  'question',
#  'particular',
#  'boys',
#  'nor',
#  'cheesy',
#  'screenplay',
#  'male',
#  'credits',
#  'memorable',
#  'interested',
#  'air',
#  'towards',
#  'meet',
#  'earlier',
#  'footage',
#  'worked',
#  'personal',
#  'island',
#  'previous',
#  'doctor',
#  'result',
#  'perfectly',
#  'features',
#  'gun',
#  'laughs',
#  'needed',
#  'effect',
#  'quickly',
#  'battle',
#  'street',
#  'hands',
#  's',
#  'unless',
#  'dance',
#  'whom',
#  'writers',
#  'write',
#  'joe',
#  'total',
#  'emotional',
#  'powerful',
#  'forward',
#  'business',
#  'mess',
#  'comment',
#  'setting',
#  'nature',
#  'background',
#  'meets',
#  'badly',
#  'season',
#  'bill',
#  'girlfriend',
#  'dramatic',
#  'superb',
#  'masterpiece',
#  'keeps',
#  'mark',
#  'crazy',
#  'realize',
#  'older',
#  'various',
#  'era',
#  'japanese',
#  'appear',
#  'baby',
#  'pay',
#  'incredibly',
#  'inside',
#  'weird',
#  'twist',
#  'directing',
#  'unique',
#  'telling',
#  'rich',
#  'fairly',
#  'plenty',
#  'brothers',
#  'beauty',
#  'front',
#  'development',
#  'present',
#  'william',
#  'sounds',
#  'outside',
#  'copy',
#  'party',
#  'apart',
#  'directors',
#  'brings',
#  'reasons',
#  'fighting',
#  'leading',
#  'secret',
#  'dumb',
#  'missing',
#  ...]
